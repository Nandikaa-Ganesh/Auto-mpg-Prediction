# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Pandas and Numpy have been used for Data Manipulation and numerical Calculations
# Matplotlib and Seaborn have been used for Data visualizations

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the data required

# %%
df = pd.read_csv("mpg.csv",  na_values='?')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Analyzing the data

# %%
df.shape
# Out:
# (398, 9)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# ### Checking for duplicate values

# %%
duplicated_rows = df[df.duplicated()]

# %%
duplicated_rows.shape
# Out:
# (0, 9)

# %% [markdown]
# There is no duplicate entries. All the fields except Column-"Name" are numerical data types.

# %% [markdown]
# ### Removing missing values

# %%
print(df.isnull().sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# There is 6 missing entries in Horsepower column

# %%
df = df.dropna(axis=0) ##removing rows - therefore axis=0

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# All missing data rows has been removed. Since very small amount of data was only missing

# %% [markdown]
# ### Inferences from dataset

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.shape
# Out:
# (392, 9)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# model_year       13
# origin            3
# name            301
# dtype: int64

# %%
df.drop(columns=['name'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 27.6 KB

# %%
sns.distplot(df['mpg'])
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
inf_values = df.isin([np.inf, -np.inf]).sum().sum()

if inf_values > 0:
    print(f"There are {inf_values} infinite values in the DataFrame.")
else:
    print("There are no infinite values in the DataFrame.")
# Out:
# There are no infinite values in the DataFrame.

# %% [markdown]
# Checked for infinite values - there were no infinite values

# %%
corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model_year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model_year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# ...

# %%
sns.heatmap(corr_matrix, annot=True, cmap='cividis', fmt='.2f')

# Show the plot
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
# Scatterplot: A scatterplot shows the relationship between two variables
sns.scatterplot(x='origin', y='mpg', data=df)
plt.show()

sns.scatterplot(x='acceleration', y='mpg', data=df)
plt.show()

sns.scatterplot(x='model_year', y='mpg', data=df)
plt.show()

sns.scatterplot(x='cylinders', y='weight', data=df)
plt.show()

# %%
# Boxplot: A boxplot shows the distribution of a continuous variable
sns.boxplot(x='acceleration', y='mpg', data=df)
plt.show()

sns.boxplot(x='origin', y='mpg', data=df)
plt.show()

sns.boxplot(x='model_year', y='mpg', data=df)
plt.show()

# %%
# Violinplot: A violinplot shows the distribution of a continuous variable
sns.violinplot(x='model_year', y='mpg', data=df)
plt.show()

# %%
# Histogram: A histogram shows the distribution of a continuous variable
sns.histplot(y='mpg', data=df)
plt.show()

# %%
# Barplot: A barplot shows the relationship between a categorical and a continuous variable
sns.barplot(x='model_year', y='mpg', data=df)
plt.show()

sns.barplot(x='cylinders', y='mpg', data=df)
plt.show()

sns.barplot(x='origin', y='mpg', data=df)
plt.show()

# %%
# Countplot: A countplot shows the count of each category in a categorical variable
sns.countplot(x='origin', data=df)
plt.show()

# %%
# Heatmap: A heatmap shows the correlation between variables
sns.heatmap(df.corr(), annot=True, cmap='inferno', fmt='.2f')
plt.show()
